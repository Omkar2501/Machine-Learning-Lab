# %%
import pandas as pd

df = pd.read_csv('loan_data.csv')
df.head()
# Out:
# Running cells with 'Python 3.14.6' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/sai/AppData/Local/Programs/Python/Python314-32/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df.info()
